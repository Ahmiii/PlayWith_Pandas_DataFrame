# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
flight_df=pd.read_csv('data.csv')

# %%
flight_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  year  month  day  dep_time  dep_delay  arr_time  \
# 0           0             1  2013      1    1     517.0        2.0     830.0
# 1           1             2  2013      1    1     533.0        4.0     850.0
# 2           2             3  2013      1    1     542.0        2.0     923.0
# 3           3             4  2013      1    1     544.0       -1.0    1004.0
# 4           4             5  2013      1    1     554.0       -6.0     812.0
#
#    arr_delay carrier tailnum  flight origin dest  air_time  distance  hour  \
# 0       11.0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0
# 1       20.0      UA  N24211    1714    LGA  IAH     227.0      1416   5.0
# 2       33.0      AA  N619AA    1141    JFK  MIA     160.0      1089   5.0
# 3      -18.0      B6  N804JB     725    JFK  BQN     183.0      1576   5.0
# 4      -25.0      DL  N668DN     461    LGA  ATL     116.0       762   5.0
#
#    minute
# 0    17.0
# 1    33.0
# 2    42.0
# ...

# %%
flight_df.isnull().sum()
# Out:
# Unnamed: 0         0
# Unnamed: 0.1       0
# year               0
# month              0
# day                0
# dep_time        8255
# dep_delay       8255
# arr_time        8713
# arr_delay       9430
# carrier            0
# tailnum         2512
# flight             0
# origin             0
# dest               0
# air_time        9430
# distance           0
# hour            8255
# minute          8255
# dtype: int64

# %%
flight_df.shape
# Out:
# (336776, 18)

# %%
flight_df.dropna(how='any',inplace=True)

# %%
flight_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# year            0
# month           0
# day             0
# dep_time        0
# dep_delay       0
# arr_time        0
# arr_delay       0
# carrier         0
# tailnum         0
# flight          0
# origin          0
# dest            0
# air_time        0
# distance        0
# hour            0
# minute          0
# dtype: int64

# %%
flight_df.shape
# Out:
# (327346, 18)

# %%
flight_df.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1      year          month            day  \
# count  327346.000000  327346.000000  327346.0  327346.000000  327346.000000
# mean   168190.637793  168191.637793    2013.0       6.564803      15.740825
# std     97510.314383   97510.314383       0.0       3.413444       8.777376
# min         0.000000       1.000000    2013.0       1.000000       1.000000
# 25%     83007.250000   83008.250000    2013.0       4.000000       8.000000
# 50%    168251.500000  168252.500000    2013.0       7.000000      16.000000
# 75%    252782.750000  252783.750000    2013.0      10.000000      23.000000
# max    336769.000000  336770.000000    2013.0      12.000000      31.000000
#
#             dep_time      dep_delay       arr_time      arr_delay  \
# count  327346.000000  327346.000000  327346.000000  327346.000000
# mean     1348.789883      12.555156    1501.908238       6.895377
# std       488.319979      40.065688     532.888731      44.633292
# ...

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327346 entries, 0 to 336769
# Data columns (total 18 columns):
# Unnamed: 0      327346 non-null int64
# Unnamed: 0.1    327346 non-null int64
# year            327346 non-null int64
# month           327346 non-null int64
# day             327346 non-null int64
# dep_time        327346 non-null float64
# dep_delay       327346 non-null float64
# arr_time        327346 non-null float64
# arr_delay       327346 non-null float64
# carrier         327346 non-null object
# tailnum         327346 non-null object
# flight          327346 non-null int64
# origin          327346 non-null object
# dest            327346 non-null object
# air_time        327346 non-null float64
# distance        327346 non-null int64
# hour            327346 non-null float64
# minute          327346 non-null float64
# dtypes: float64(7), int64(7), object(4)
# memory usage: 47.5+ MB

# %%
col=flight_df.columns
col
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'year', 'month', 'day', 'dep_time',
#        'dep_delay', 'arr_time', 'arr_delay', 'carrier', 'tailnum', 'flight',
#        'origin', 'dest', 'air_time', 'distance', 'hour', 'minute'],
#       dtype='object')

# %%
for i in col:
    plt.scatter(x=i,y='dep_delay',data=flight_df)
    plt.xlabel(i)
    plt.ylabel('Delay')
    plt.show()
