# %%
import pandas as pd

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[movies.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %% [markdown]
# Logical Operators

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
movies[(movies.duration>=200) & (movies.genre=='Action')]
# Out:
#      star_rating                            title content_rating   genre  \
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
movies[(movies.duration>=200) | (movies.genre=='Action')]
# Out:
#      star_rating                                            title  \
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 7            8.9    The Lord of the Rings: The Return of the King
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# 36           8.6                              Saving Private Ryan
# 37           8.6                          Raiders of the Lost Ark
# 43           8.5                            The Dark Knight Rises
# 44           8.5                                        Gladiator
# 45           8.5                       Terminator 2: Judgment Day
# ...

# %%
movies[(movies.genre=='Action') | (movies.genre=='Crime') | (movies.genre=='Romance')]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# 21           8.7                                      City of God
# 23           8.7                               The Usual Suspects
# 28           8.6                           Leon: The Professional
# 34           8.6                               American History X
# ...

# %%
movies[(movies.star_rating>=8) & ((movies.genre=='Action') | (movies.genre=='Crime') | (movies.genre=='Romance'))]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 1            9.2                                   The Godfather
# 2            9.1                          The Godfather: Part II
# 3            9.0                                 The Dark Knight
# 4            8.9                                    Pulp Fiction
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 21           8.7                                     City of God
# 23           8.7                              The Usual Suspects
# 28           8.6                          Leon: The Professional
# 34           8.6                              American History X
# ...

# %%
#One more way to wright
movies[movies.genre.isin(['Drama','Action','Crime'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...
